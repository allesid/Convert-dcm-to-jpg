# %%
from pydicom.pixel_data_handlers.util import apply_modality_lut
import matplotlib.pyplot as plt
from pydicom import dcmread
from pydicom.data import get_testdata_files
import os.path
dpath = "./DCM_imgs_2D/TCGA-K7-A6G5/11-14-2000-NA-CT UPPER ABD W CONT-01365/4.000000-ARTERIAL-75682"
# The path to a pydicom test dataset
# path = get_testdata_file(os.path.join(dpath, "1-70.dcm"))
ds = dcmread(os.path.join(dpath, "1-16.dcm"))
# `arr` is a numpy.ndarray
arr = ds.pixel_array

plt.imshow(arr, cmap="gray")
plt.show()
ds["PatientID"]
# get_testdata_files()
# for elem in ds.elements():)
# print(elem)

# hu = apply_modality_lut(arr, ds)
# print(hu)
# for k in ds.keys():
    # print(ds[k])
# Out:
# (0010, 0020) Patient ID                          LO: 'TCGA-K7-A6G5'
